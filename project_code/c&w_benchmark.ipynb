# %% [markdown]
# # Test of the benchmark examples. C&W Savings Algorithm

# %% [markdown]
# ## Import dependencies

# %%
import savings

# %% [markdown]
# ## Benchmark table

# %% [markdown]
# **Table 1**. Results for 33 standard benchmarks (multi-thread C implementation) (Juan et al., 2011)
#
# ![Benchmark table](../project_miscellany/images/benchmark_table.png)

# %% [markdown]
# ## Solution plot and cost review

# %% [markdown]
# It is possible to try other solutions and examine the cost of each bechmark. In this way it is possible to verify that the implemented algorithm obtains the same solutions as those obtained in the tests (Juan et al., 2011).
#
# Attention has to be paid when establishing the capacity of the vehicle and giving the function the tabulated value for that test.

# %%
solution = savings.cw_savings(instance_name='P-n101-k4', veh_capacity=400)
print('C&W solution cost = {}'.format(solution.cost))
solution.plot_routes()
# Out:
# C&W solution cost = 765.3793981291958

# %% [markdown]
# ## Bibliography
#
#   Juan, A.A., Faulin, J., Jorba, J., Riera, D., Masip, D., Barrios, B., 2011. On the use of Monte Carlo simulation, cache and splitting techniques to improve the Clarke and Wright savings heuristics. Journal of the Operational Research Society 62, 1085–1097. https://doi.org/10.1057/jors.2010.29
