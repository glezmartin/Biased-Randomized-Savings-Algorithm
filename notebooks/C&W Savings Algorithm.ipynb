# %%
import sys
sys.path.append('../src/')
import savings_algorithm
from IPython.display import Image

# %% [markdown]
# # Test of benchmark examples. C&W Savings Algorithm
#
# In this Jupyter notebook we can see how the implementation of Clarke and Wright's savings heuristic works.
#
# By means of the function cw_savings a solution graph is generated that we can visualize using the plot_routes method.

# %% [markdown]
# ## Benchmark table

# %%
Image(filename='../reports/figures/benchmark_table.png')

# %% [markdown]
# __Table 1.__ Results for 33 standard benchmarks (multi-thread C implementation) (Juan et al., 2011)

# %% [markdown]
# ## Solution plot and cost review
# It is possible to try other solutions and examine the cost of each bechmark (CWS Sol. column). In this way it is possible to verify that the implemented algorithm obtains the same solutions as those obtained in the tests (Juan et al., 2011).

# %%
solution = savings_algorithm.cw_savings('P-n101-k4')
solution.plot_routes()

# %% [markdown]
# ## Bibliography
#
# Juan, A.A., Faulin, J., Jorba, J., Riera, D., Masip, D., Barrios, B., 2011. On the use of Monte Carlo simulation, cache and splitting techniques to improve the Clarke and Wright savings heuristics. Journal of the Operational Research Society 62, 1085–1097. https://doi.org/10.1057/jors.2010.29
